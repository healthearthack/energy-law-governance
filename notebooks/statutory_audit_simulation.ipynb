# %% [markdown]
# # Statutory Audit & Corporate Diligence Simulation
# ### Doctoral Defense Monograph Series — Part 3: Global Mineral Law & Statutory Economics
# **Candidate:** `@healthearthack` | **Affiliation:** Metaknews LLC / thepolka.cloud
#
# ---
#
# ## 1. Legal & Regulatory Framework
#
# This simulation models institutional bankability and statutory compliance under:
# 1. **United States Inflation Reduction Act (IRA)** Sections 30D and 45X.
# 2. **European Union Critical Raw Materials Act (CRMA)** Regulation (EU) 2024/1252.
# 3. **EPA Safe Drinking Water Act (SDWA)** Underground Injection Control (UIC) Class II to Class V re-permitting.

# %%
import json
import numpy as np

# Production parameters from Repo 2 (smackover-oil-lithium-energy)
ANNUAL_LCE_METRIC_TONS = 10534.6
PRODUCTION_COST_USD_PER_TON = 4200.0
DOMESTIC_EXTRACTION_PCT = 100.0

# IRA Section 45X: 10% Production Tax Credit
annual_opex = ANNUAL_LCE_METRIC_TONS * PRODUCTION_COST_USD_PER_TON
tax_credit_45x = annual_opex * 0.10

print(f"[*] Annual LCE Production:          {ANNUAL_LCE_METRIC_TONS:,.1f} MT/year")
print(f"[*] Total Production Cost:          ${annual_opex:,.2f} USD")
print(f"[*] IRA Section 45X Tax Credit:     ${tax_credit_45x:,.2f} USD/year")
print(f"[*] IRA Section 30D EV Eligibility: QUALIFIED (100% Domestic Content)")

# %% [markdown]
# ## 2. EPA Underground Injection Control (UIC) Capex & Time Savings
# Converting existing petroleum Class II disposal wellbores versus drilling greenfield Class V wells.

# %%
greenfield_drilling_cost_usd = 8500000.0
wellbore_reentry_conversion_usd = 1800000.0
capex_savings_per_well = greenfield_drilling_cost_usd - wellbore_reentry_conversion_usd
total_cluster_savings = capex_savings_per_well * 3

print(f"[✓] Greenfield Drilling Capex (3 wells):  ${greenfield_drilling_cost_usd * 3:,.2f} USD")
print(f"[✓] Repurposed Wellbore Re-entry:         ${wellbore_reentry_conversion_usd * 3:,.2f} USD")
print(f"[✓] Net Capital Expenditure Savings:      ${total_cluster_savings:,.2f} USD (78.8% Capex Reduction)")
